# %% [markdown]
# # Imports

# %%
from typing import List
import requests
import pandas as pd

from scraper import scrape
from downloader import download_and_extract_zips

# %%
DATA_PATH_ORIG = '../DATA/original'
DATA_PATH_PREP = '../DATA/prepared'

# %%
AUTHORS = {
    'ivan_vazov': ["Българският език", "Отечество любезно, как хубаво си ти", "При Рилския манастир", "Елате ни вижте", "Линее нашто поколенье", "Левски", "Паисий", "Кочо", "Опълченците на Шипка", "Дядо Йоцо гледа", "Чичовци", "Под игото"],
    'aleko-konstantinov': ["Разни хора, разни идеали I", "Разни хора, разни идеали II", "Разни хора, разни идеали III", "Разни хора, разни идеали IV", "Бай Ганьо"],
    'jordan-jovkov': ["Песента на колелетата", "Последна радост", "Шибил", "През чумавото", "Индже", "Албена", "Другоселец", "Серафим"],
    'elin-pelin': ["Ветрената мелница", "Косачи", "Задушница", "Мечтатели", "На оня свят", "Андрешко", "Чорба от греховете на отец Никодим", "Занемелите камбани", "Гераците"],
    'dimityr-dimov': ["Тютюн"],
    'dimityr-talev': ["Железният светилник"],
}

URL = 'https://chitanka.info/person'

# %% [markdown]
# # Get scraped data

# %%
df = scrape(URL, AUTHORS.keys())
df
# Out:
#              author                     title  \
# 0        ivan_vazov                   Чичовци
# 1        ivan_vazov                 Под игото
# 2        ivan_vazov                 Нова земя
# 3        ivan_vazov           Кардашев на лов
# 4        ivan_vazov              Най-големият
# ...             ...                       ...
# 1517  dimityr-talev        Гласовете ви чувам
# 1518  dimityr-talev            Щитове каменни
# 1519  dimityr-talev  Пепеляшка и царският син
# 1520  dimityr-talev                   Погибел
# 1521  dimityr-talev            Крилатата кула
#
#                                           download_link
# 0     https://chitanka.info/text/3757-chichovtsi.txt...
# 1     https://chitanka.info/text/3753-pod-igoto.txt.zip
# 2     https://chitanka.info/text/3754-nova-zemja.txt...
# 3     https://chitanka.info/text/3762-kardashev-na-l...
# 4     https://chitanka.info/text/4008-najgolemijat.t...
# ...                                                 ...
# 1517  https://chitanka.info/text/3156-glasovete-vi-c...
# 1518  https://chitanka.info/text/4834-shtitove-kamen...
# 1519  https://chitanka.info/text/4961-pepeljashka-i-...
# 1520    https://chitanka.info/text/4989-pogibel.txt.zip
# 1521  https://chitanka.info/text/11482-krilatata-kul...
#
# [1522 rows x 3 columns]

# %%
all_texts = sum(AUTHORS.values(), [])
all_texts[:5]

# check whether all texts you're going to use are present in the dataframe
all(all(text in set(df.query('author == author')['title']) for text in AUTHORS[author]) for author in AUTHORS)
# Out:
# True

# %% [markdown]
# # Subset only texts of interest

# %%
df_full = df.query('title in @all_texts').reset_index(drop=True)
df_full
# Out:
#                 author                                title  \
# 0           ivan_vazov                              Чичовци
# 1           ivan_vazov                            Под игото
# 2           ivan_vazov                     Българският език
# 3           ivan_vazov                                 Кочо
# 4           ivan_vazov                               Левски
# 5           ivan_vazov                Линее нашто поколенье
# 6           ivan_vazov                 Опълченците на Шипка
# 7           ivan_vazov  Отечество любезно, как хубаво си ти
# 8           ivan_vazov                               Паисий
# 9           ivan_vazov                 При Рилския манастир
# 10          ivan_vazov                       Елате ни вижте
# 11          ivan_vazov                      Дядо Йоцо гледа
# 12  aleko-konstantinov           Разни хора, разни идеали I
# 13  aleko-konstantinov          Разни хора, разни идеали II
# 14  aleko-konstantinov         Разни хора, разни идеали III
# 15  aleko-konstantinov          Разни хора, разни идеали IV
# 16  aleko-konstantinov                            Бай Ганьо
# 17       jordan-jovkov                      Последна радост
# 18       jordan-jovkov                               Албена
# 19       jordan-jovkov                               Албена
# 20       jordan-jovkov                           Другоселец
# 21       jordan-jovkov                                Индже
# 22       jordan-jovkov                Песента на колелетата
# 23       jordan-jovkov                        През чумавото
# 24       jordan-jovkov                              Серафим
# 25       jordan-jovkov                              Серафим
# 26       jordan-jovkov                                Шибил
# 27          elin-pelin                             Гераците
# 28          elin-pelin                               Косачи
# 29          elin-pelin                             Андрешко
# 30          elin-pelin                    Ветрената мелница
# 31          elin-pelin                            Задушница
# 32          elin-pelin                   Занемелите камбани
# 33          elin-pelin                               Косачи
# 34          elin-pelin                            Мечтатели
# 35          elin-pelin                          На оня свят
# 36          elin-pelin   Чорба от греховете на отец Никодим
# 37       dimityr-dimov                                Тютюн
# 38       dimityr-dimov                                Тютюн
# 39       dimityr-talev                  Железният светилник
#
#                                         download_link
# 0   https://chitanka.info/text/3757-chichovtsi.txt...
# 1   https://chitanka.info/text/3753-pod-igoto.txt.zip
# 2   https://chitanka.info/text/5189-bylgarskijat-e...
# 3       https://chitanka.info/text/3851-kocho.txt.zip
# 4      https://chitanka.info/text/3849-levski.txt.zip
# 5   https://chitanka.info/text/5208-linee-nashto-p...
# 6   https://chitanka.info/text/3860-opylchentsite-...
# 7   https://chitanka.info/text/5163-otechestvo-lju...
# 8      https://chitanka.info/text/3854-paisij.txt.zip
# 9   https://chitanka.info/text/4314-pri-rilskija-m...
# 10  https://chitanka.info/text/4717-elate-ni-vizht...
# 11  https://chitanka.info/text/4176-djado-jotso-gl...
# 12  https://chitanka.info/text/3709-razni-hora-raz...
# 13  https://chitanka.info/text/3710-razni-hora-raz...
# 14  https://chitanka.info/text/3711-razni-hora-raz...
# 15  https://chitanka.info/text/3712-razni-hora-raz...
# 16  https://chitanka.info/text/3706-baj-ganxo.txt.zip
# 17  https://chitanka.info/text/7896-posledna-rados...
# 18     https://chitanka.info/text/7866-albena.txt.zip
# 19     https://chitanka.info/text/7879-albena.txt.zip
# 20  https://chitanka.info/text/7885-drugoselets.tx...
# 21     https://chitanka.info/text/7891-indzhe.txt.zip
# 22  https://chitanka.info/text/7895-pesenta-na-kol...
# 23  https://chitanka.info/text/7893-prez-chumavoto...
# 24   https://chitanka.info/text/48174-Serafim.txt.zip
# 25    https://chitanka.info/text/7845-serafim.txt.zip
# 26     https://chitanka.info/text/2969-shibil.txt.zip
# 27  https://chitanka.info/text/5624-geratsite.txt.zip
# 28    https://chitanka.info/text/5667-kosachi.txt.zip
# 29  https://chitanka.info/text/5283-andreshko.txt.zip
# 30  https://chitanka.info/text/5301-vetrenata-meln...
# 31  https://chitanka.info/text/5304-zadushnitsa.tx...
# 32  https://chitanka.info/text/5418-zanemelite-kam...
# 33    https://chitanka.info/text/5290-kosachi.txt.zip
# 34  https://chitanka.info/text/5614-mechtateli.txt...
# 35  https://chitanka.info/text/5303-na-onja-svjat....
# 36  https://chitanka.info/text/5420-chorba-ot-greh...
# 37    https://chitanka.info/text/2760-tjutjun.txt.zip
# 38    https://chitanka.info/text/5799-tjutjun.txt.zip
# 39  https://chitanka.info/text/569-zheleznijat-sve...

# %%
for auth in AUTHORS:
    print(auth, end=' => ')
    print(set(df_full.query("author == @auth")['title']) == set(AUTHORS[auth]), end=' | ')
    print(len(df_full.query("author == @auth")['title']) == len(AUTHORS[auth]), end='')
    print()
# Out:
# ivan_vazov => True | True
# aleko-konstantinov => True | True
# jordan-jovkov => True | False
# elin-pelin => True | False
# dimityr-dimov => True | False
# dimityr-talev => True | True

# %%
# jordan-jovkov has Албена as an "Пиеса" and as a "Разказ". We need the second one.
# Its download link includes 7879. Therefore, drop row with index 18.
# There are also two vesions of Серафим. Not sure why. Keeping one of them. Drop row with index 25.

# elin-pelin has Косачи as an "Поезия" and as a "Разказ". We need the second one.
# Its download link includes 7879. Therefore, drop row with index 28.

# dimityr-dimov has two versions of "Тютюн" due to political reasons. We'll work with the most recent one.
# Its download link includes 2760. Therefore, drop row with index 38.

df_full = df_full.drop([18, 25, 28, 38])

for auth in AUTHORS:
    print(auth, end=' => ')
    print(set(df_full.query("author == @auth")['title']) == set(AUTHORS[auth]), end=' | ')
    print(len(df_full.query("author == @auth")['title']) == len(AUTHORS[auth]), end='')
    print()
# Out:
# ivan_vazov => True | True
# aleko-konstantinov => True | True
# jordan-jovkov => True | True
# elin-pelin => True | True
# dimityr-dimov => True | True
# dimityr-talev => True | True

# %%
df_full
# Out:
#                 author                                title  \
# 0           ivan_vazov                              Чичовци
# 1           ivan_vazov                            Под игото
# 2           ivan_vazov                     Българският език
# 3           ivan_vazov                                 Кочо
# 4           ivan_vazov                               Левски
# 5           ivan_vazov                Линее нашто поколенье
# 6           ivan_vazov                 Опълченците на Шипка
# 7           ivan_vazov  Отечество любезно, как хубаво си ти
# 8           ivan_vazov                               Паисий
# 9           ivan_vazov                 При Рилския манастир
# 10          ivan_vazov                       Елате ни вижте
# 11          ivan_vazov                      Дядо Йоцо гледа
# 12  aleko-konstantinov           Разни хора, разни идеали I
# 13  aleko-konstantinov          Разни хора, разни идеали II
# 14  aleko-konstantinov         Разни хора, разни идеали III
# 15  aleko-konstantinov          Разни хора, разни идеали IV
# 16  aleko-konstantinov                            Бай Ганьо
# 17       jordan-jovkov                      Последна радост
# 19       jordan-jovkov                               Албена
# 20       jordan-jovkov                           Другоселец
# 21       jordan-jovkov                                Индже
# 22       jordan-jovkov                Песента на колелетата
# 23       jordan-jovkov                        През чумавото
# 24       jordan-jovkov                              Серафим
# 26       jordan-jovkov                                Шибил
# 27          elin-pelin                             Гераците
# 29          elin-pelin                             Андрешко
# 30          elin-pelin                    Ветрената мелница
# 31          elin-pelin                            Задушница
# 32          elin-pelin                   Занемелите камбани
# 33          elin-pelin                               Косачи
# 34          elin-pelin                            Мечтатели
# 35          elin-pelin                          На оня свят
# 36          elin-pelin   Чорба от греховете на отец Никодим
# 37       dimityr-dimov                                Тютюн
# 39       dimityr-talev                  Железният светилник
#
#                                         download_link
# 0   https://chitanka.info/text/3757-chichovtsi.txt...
# 1   https://chitanka.info/text/3753-pod-igoto.txt.zip
# 2   https://chitanka.info/text/5189-bylgarskijat-e...
# 3       https://chitanka.info/text/3851-kocho.txt.zip
# 4      https://chitanka.info/text/3849-levski.txt.zip
# 5   https://chitanka.info/text/5208-linee-nashto-p...
# 6   https://chitanka.info/text/3860-opylchentsite-...
# 7   https://chitanka.info/text/5163-otechestvo-lju...
# 8      https://chitanka.info/text/3854-paisij.txt.zip
# 9   https://chitanka.info/text/4314-pri-rilskija-m...
# 10  https://chitanka.info/text/4717-elate-ni-vizht...
# 11  https://chitanka.info/text/4176-djado-jotso-gl...
# 12  https://chitanka.info/text/3709-razni-hora-raz...
# 13  https://chitanka.info/text/3710-razni-hora-raz...
# 14  https://chitanka.info/text/3711-razni-hora-raz...
# 15  https://chitanka.info/text/3712-razni-hora-raz...
# 16  https://chitanka.info/text/3706-baj-ganxo.txt.zip
# 17  https://chitanka.info/text/7896-posledna-rados...
# 19     https://chitanka.info/text/7879-albena.txt.zip
# 20  https://chitanka.info/text/7885-drugoselets.tx...
# 21     https://chitanka.info/text/7891-indzhe.txt.zip
# 22  https://chitanka.info/text/7895-pesenta-na-kol...
# 23  https://chitanka.info/text/7893-prez-chumavoto...
# 24   https://chitanka.info/text/48174-Serafim.txt.zip
# 26     https://chitanka.info/text/2969-shibil.txt.zip
# 27  https://chitanka.info/text/5624-geratsite.txt.zip
# 29  https://chitanka.info/text/5283-andreshko.txt.zip
# 30  https://chitanka.info/text/5301-vetrenata-meln...
# 31  https://chitanka.info/text/5304-zadushnitsa.tx...
# 32  https://chitanka.info/text/5418-zanemelite-kam...
# 33    https://chitanka.info/text/5290-kosachi.txt.zip
# 34  https://chitanka.info/text/5614-mechtateli.txt...
# 35  https://chitanka.info/text/5303-na-onja-svjat....
# 36  https://chitanka.info/text/5420-chorba-ot-greh...
# 37    https://chitanka.info/text/2760-tjutjun.txt.zip
# 39  https://chitanka.info/text/569-zheleznijat-sve...

# %% [markdown]
# # Download data

# %%
urls = df_full['download_link'].tolist()
output_dir = '../DATA/original'
names = download_and_extract_zips(urls, output_dir)
# Out:
# Extracted 01: ivan_vazov_tbc_chichovtsi.txt
# Extracted 02: ivan_vazov_tbc_pod_igoto.txt
# Extracted 03: ivan_vazov_bylgarskijat_ezik.txt
# Extracted 04: ivan_vazov_kocho.txt
# Extracted 05: ivan_vazov_levski.txt
# Extracted 06: ivan_vazov_linee_nashto_pokolenxe.txt
# Extracted 07: ivan_vazov_opylchentsite_na_shipka.txt
# Extracted 08: ivan_vazov_otechestvo_ljubeznokak_hubavo_si_ti.txt
# Extracted 09: ivan_vazov_paisij.txt
# Extracted 10: ivan_vazov_pri_rilskija_manastir.txt
# Extracted 11: ivan_vazov,elate_ni_vizhte.txt
# Extracted 12: ivan_vazov_djado_jotso_gleda.txt
# Extracted 13: aleko_konstantinov_rhri_razni_horarazni_ideali_i.txt
# Extracted 14: aleko_konstantinov_rhri_razni_horarazni_ideali_ii.txt
# Extracted 15: aleko_konstantinov_rhri_razni_horarazni_ideali_iii.txt
# Extracted 16: aleko_konstantinov_rhri_razni_horarazni_ideali_iv.txt
# Extracted 17: aleko_konstantinov_baj_ganxo.txt
# Extracted 18: jordan_jovkov_posledna_radost.txt
# Extracted 19: jordan_jovkov_albena.txt
# Extracted 20: jordan_jovkov_drugoselets.txt
# Extracted 21: jordan_jovkov_indzhe.txt
# Extracted 22: jordan_jovkov_pesenta_na_koleletata.txt
# Extracted 23: jordan_jovkov_prez_chumavoto.txt
# Extracted 24: jordan_jovkov_serafim.txt
# Extracted 25: jordan_jovkov_shibil.txt
# Extracted 26: elin_pelin_geratsite.txt
# Extracted 27: elin_pelin_andreshko.txt
# Extracted 28: elin_pelin_vetrenata_melnitsa.txt
# Extracted 29: elin_pelin_zadushnitsa.txt
# Extracted 30: elin_pelin_zanemelite_kambani.txt
# Extracted 31: elin_pelin_kosachi.txt
# Extracted 32: elin_pelin_mechtateli.txt
# Extracted 33: elin_pelin_na_onja_svjat.txt
# Extracted 34: elin_pelin_chorba_ot_grehovete_na_otets_nikodim.txt
# Extracted 35: dimityr_dimov_tjutjun.txt
# Extracted 36: dimityr_talev_pt_zheleznijat_svetilnik.txt

# %% [markdown]
# # Add text

# %%
names[:5]
# Out:
# ['ivan_vazov_tbc_chichovtsi.txt',
#  'ivan_vazov_tbc_pod_igoto.txt',
#  'ivan_vazov_bylgarskijat_ezik.txt',
#  'ivan_vazov_kocho.txt',
#  'ivan_vazov_levski.txt']

# %%
def get_text(filename: str) -> List[str]:
    with open(filename, 'r') as f:
        tokens = f.read().split()
    return lines

# %%
get_text(df_full['text'][0])

# %%
df_full['text'].map(get_text)

# %% [markdown]
# # Saving to files

# %%
f'{DATA_PATH_PREP}/01_df_full_links.pkl'

# %%
df_full.to_pickle(f'{DATA_PATH_PREP}/01_df_full_links.pkl')
