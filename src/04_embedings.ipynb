# %% [markdown]
# # Imports

# %%
import pickle

import pandas as pd
pd.set_option('max_colwidth', 150)
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
DATA_PATH_PREP = '../DATA/prepared'

# %% [markdown]
# # Load data

# %%
df_full_soft = pd.read_pickle(f'{DATA_PATH_PREP}/03_df_full_soft.pkl')
df_full_med = pd.read_pickle(f'{DATA_PATH_PREP}/03_df_full_med.pkl')
df_full_hard = pd.read_pickle(f'{DATA_PATH_PREP}/03_df_full_hard.pkl')

# %%
df_full_soft.head()
# Out:
#                                                                                                                                                     text  \
# 0  [галерия, от, типове, и, нрави, български, в, турско, време, i, ., общество, утринното, лятно, слънце, изскокна, високо, над, стара, планина, ., п...
# 1  [част, първа, i, ., гост, тая, прохладна, майска, вечер, чорбаджи, марко, ,, гологлав, ,, по, халат, ,, вечеряше, с, челядта, си, на, двора, ., го...
# 2  [език, свещен, на, моите, деди, език, на, мъки, ,, стонове, вековни, ,, език, на, тая, ,, дето, ни, роди, за, радост, не, —, за, ядове, отровни, ....
# 3  [защитата, на, перущица, o, ,, движенье, славно, ,, о, ,, мрачно, движенье, ,, дни, на, борба, горда, ,, о, ,, дни, на, паденье, !, епопея, тъмна,...
# 4  [манастирът, тесен, за, мойта, душа, е, ., кога, човек, дойде, тук, да, се, покае, ,, трябва, да, забрави, греховния, мир, ,, да, бяга, съблазни, ...
#
#        author
# 0  ivan_vazov
# 1  ivan_vazov
# 2  ivan_vazov
# 3  ivan_vazov
# 4  ivan_vazov

# %% [markdown]
# # Term Frequency - Inverse Document Frequency Table

# %%
def identity(x):
  return x

tfidf_soft = TfidfVectorizer(
    tokenizer=identity,
    preprocessor=identity,
    token_pattern=None,
    lowercase=False,
    stop_words=None,
    min_df=2,
)

data_tfidf = tfidf_soft.fit_transform(df_full_soft['text'])
data_table_soft = pd.DataFrame(
    data_tfidf.toarray(),
    columns=tfidf_soft.get_feature_names_out(),
    index=df_full_soft.index
)
data_table_soft['author'] = df_full_soft['author']
data_table_soft.head()
# Out:
#           !  ! )  ! ) ,       ! [     ! [ *  ! »       ! а      ! аз  \
# 0  0.087453  0.0    0.0  0.000939  0.000939  0.0  0.001094  0.003564
# 1  0.047244  0.0    0.0  0.000000  0.000000  0.0  0.000579  0.000754
# 2  0.063458  0.0    0.0  0.000000  0.000000  0.0  0.000000  0.000000
# 3  0.142968  0.0    0.0  0.000000  0.000000  0.0  0.000000  0.000000
# 4  0.052077  0.0    0.0  0.000000  0.000000  0.0  0.000000  0.000000
#
#      ! аз ,  ! аз съм  ...       … …     … … и     … … …   … … … и   … … … …  \
# 0  0.000939  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000994  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  ...  0.257627  0.013559  0.244068  0.013559  0.230508
# 4  0.000000  0.000000  ...  0.235098  0.011195  0.223903  0.011195  0.212708
#
#           №      № 19    № 19 .  № 19 . тираж      author
# 0  0.000000  0.000000  0.000000      0.000000  ivan_vazov
# 1  0.000000  0.000000  0.000000      0.000000  ivan_vazov
# 2  0.000000  0.000000  0.000000      0.000000  ivan_vazov
# 3  0.012621  0.012621  0.012621      0.012621  ivan_vazov
# 4  0.010420  0.010420  0.010420      0.010420  ivan_vazov
#
# [5 rows x 41423 columns]

# %%
tfidf_med = TfidfVectorizer(
    tokenizer=identity,
    preprocessor=identity,
    token_pattern=None,
    lowercase=False,
    stop_words=None,
    min_df=2
)

data_tfidf = tfidf_med.fit_transform(df_full_med['text'])
data_table_med = pd.DataFrame(
    data_tfidf.toarray(),
    columns=tfidf_med.get_feature_names_out(),
    index=df_full_med.index
)
data_table_med['author'] = df_full_med['author']
data_table_med.head()
# Out:
#           !  ! )  ! ) ,       ! [     ! [ *  ! »       ! а      ! аз  \
# 0  0.085731  0.0    0.0  0.000921  0.000921  0.0  0.001073  0.003493
# 1  0.046539  0.0    0.0  0.000000  0.000000  0.0  0.000570  0.000743
# 2  0.062363  0.0    0.0  0.000000  0.000000  0.0  0.000000  0.000000
# 3  0.141259  0.0    0.0  0.000000  0.000000  0.0  0.000000  0.000000
# 4  0.051592  0.0    0.0  0.000000  0.000000  0.0  0.000000  0.000000
#
#      ! аз ,  ! аз съм  ...       … …     … … и     … … …   … … … и   … … … …  \
# 0  0.000921  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000979  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  ...  0.254548  0.013397  0.241151  0.013397  0.227753
# 4  0.000000  0.000000  ...  0.232911  0.011091  0.221820  0.011091  0.210729
#
#           №      № 19    № 19 .  № 19 . тираж      author
# 0  0.000000  0.000000  0.000000      0.000000  ivan_vazov
# 1  0.000000  0.000000  0.000000      0.000000  ivan_vazov
# 2  0.000000  0.000000  0.000000      0.000000  ivan_vazov
# 3  0.012470  0.012470  0.012470      0.012470  ivan_vazov
# 4  0.010323  0.010323  0.010323      0.010323  ivan_vazov
#
# [5 rows x 43440 columns]

# %%
tfidf_hard = TfidfVectorizer(
    tokenizer=identity,
    preprocessor=identity,
    token_pattern=None,
    lowercase=False,
    stop_words=None,
    min_df=2
)

data_tfidf = tfidf_hard.fit_transform(df_full_hard['text'])
data_table_hard = pd.DataFrame(
    data_tfidf.toarray(),
    columns=tfidf_hard.get_feature_names_out(),
    index=df_full_med.index
)
data_table_hard['author'] = df_full_hard['author']
data_table_hard.head()
# Out:
#           é    а   аа  аба  абе    август     авджи      авра     автор  \
# 0  0.007437  0.0  0.0  0.0  0.0  0.002276  0.000000  0.002479  0.000000
# 1  0.000000  0.0  0.0  0.0  0.0  0.000000  0.004326  0.004326  0.003972
# 2  0.000000  0.0  0.0  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.0  0.0  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.0  0.0  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
#         ага  ...  ясн лича  ясн туй  ясн чува  ясъл     ятага  ято       яхн  \
# 0  0.010592  ...       0.0      0.0       0.0   0.0  0.000000  0.0  0.000000
# 1  0.007393  ...       0.0      0.0       0.0   0.0  0.004326  0.0  0.004326
# 2  0.000000  ...       0.0      0.0       0.0   0.0  0.000000  0.0  0.000000
# 3  0.000000  ...       0.0      0.0       0.0   0.0  0.000000  0.0  0.000000
# 4  0.000000  ...       0.0      0.0       0.0   0.0  0.000000  0.0  0.000000
#
#     яхн бял  яхн бял кон      author
# 0  0.000000     0.000000  ivan_vazov
# 1  0.004326     0.004326  ivan_vazov
# 2  0.000000     0.000000  ivan_vazov
# 3  0.000000     0.000000  ivan_vazov
# 4  0.000000     0.000000  ivan_vazov
#
# [5 rows x 10370 columns]

# %% [markdown]
# # Saving to files

# %%
data_table_soft.to_pickle(f'{DATA_PATH_PREP}/04_data_table_soft.pkl')
data_table_med.to_pickle(f'{DATA_PATH_PREP}/04_data_table_med.pkl')
data_table_hard.to_pickle(f'{DATA_PATH_PREP}/04_data_table_hard.pkl')

pickle.dump(tfidf_soft, open(f'{DATA_PATH_PREP}/04_vectorizer_soft.pkl', 'wb'))
pickle.dump(tfidf_med, open(f'{DATA_PATH_PREP}/04_vectorizer_med.pkl', 'wb'))
pickle.dump(tfidf_hard, open(f'{DATA_PATH_PREP}/04_vectorizer_hard.pkl', 'wb'))
